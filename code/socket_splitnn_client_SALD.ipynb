# %% [markdown]
# ## Import required packages

# %%
from __future__ import print_function, division
import os
import struct
import socket
import pickle

import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib

import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchmetrics import PearsonCorrCoef

import scipy.stats as stats
import h5py
import gc
import time
from tqdm import tqdm

# %% [markdown]
# # Split 3D-CNN Client Side
# This code is the server part of CIFAR10 split 3D-CNN model for **multi** client and a server.

# %%
# !pip install numba
from numba import cuda
device = cuda.get_current_device()
device.reset()
# Out:
# Requirement already satisfied: numba in /home/guest2/miniconda3/envs/split_env/lib/python3.9/site-packages (0.56.4)
# Requirement already satisfied: setuptools in /home/guest2/miniconda3/envs/split_env/lib/python3.9/site-packages (from numba) (66.0.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/guest2/miniconda3/envs/split_env/lib/python3.9/site-packages (from numba) (0.39.1)
# Requirement already satisfied: numpy<1.24,>=1.18 in /home/guest2/miniconda3/envs/split_env/lib/python3.9/site-packages (from numba) (1.23.5)

# %% [markdown]
# ## Set HyperParameter

# %%
users = 3 # number of clients
epoch = 50  # default

# %%
batch_size = 5
num_workers = 8

# %% [markdown]
# ## SET CUDA

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
#device = "cpu"
torch.manual_seed(777)
if device =="cuda:0":
    torch.cuda.manual_seed_all(777)

# %%
# client_order = int(input("client_order(start from 0): "))
client_order = 0

# %% [markdown]
# ## Data load

# %%
class MRIDataset(Dataset):
    def __init__(self, csv_file, root_dir, transform = None):
        """
        Args:
            csv_file (string): csv 파일의 경로
            root_dir (string): 모든 이미지가 존재하는 디렉토리 경로
            transform (callable, optional): 샘플에 적용될 Optional transform
        """
        self.mri_annotation = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        
    def __len__(self):
        return len(self.mri_annotation)
    
    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        try:
            img_name = os.path.join(self.root_dir,'wmsub-0'+ str(self.mri_annotation.iloc[idx, 0])+ '_T1w.nii')
            mri_image = nib.load(img_name).get_fdata()
            mri_age = self.mri_annotation.iloc[idx, 1]
            sample = {'image': mri_image, 'mri_age': mri_age}
        except:
            return None
            
        return mri_image, mri_age
    
def collate_fn(batch):
    batch = list(filter(lambda x: x is not None, batch))
    return torch.utils.data.dataloader.default_collate(batch)

def flatten(lst):
    result = []
    for item in lst:
        if type(item) == list :
            result += flatten(item)
        else:
            result += [item]
    return result

# %%
mri_train_dataset = MRIDataset(csv_file = './FLdata/4_SALD/SALD_Phenotype_train.csv', root_dir = './FLdata/4_SALD/T1w/wm/')
mri_test_dataset = MRIDataset(csv_file = './FLdata/4_SALD/SALD_Phenotype_test.csv', root_dir = './FLdata/4_SALD/T1w/wm/')
mri_val_dataset = MRIDataset(csv_file = './FLdata/4_SALD/SALD_Phenotype_validation.csv', root_dir = './FLdata/4_SALD/T1w/wm/')
model_PATH = './model/CheckpointSALD.pt'

# %%
train_loader = DataLoader(mri_train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, collate_fn=collate_fn, drop_last = True)
test_loader = DataLoader(mri_test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, collate_fn=collate_fn, drop_last = True)
val_loader = DataLoader(mri_val_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, collate_fn=collate_fn, drop_last = True)

# %%
x_train, y_train = next(iter(train_loader))
print(len(train_loader))
print(x_train.size())
print(y_train.size())
# Out:
# 68
# torch.Size([5, 113, 137, 113])
# torch.Size([5])

# %% [markdown]
# ### Set other hyperparameters in the model
# Hyperparameters here should be same with the server side.

# %%
class CNN3DModel(nn.Module):
    def __init__(self):
        super(CNN3DModel, self).__init__()
        
        
        self.client_block = nn.Sequential(
            # First Block
            nn.Conv3d(1, 16, kernel_size=3, padding=1, stride=1),
            nn.ReLU(),
            
            nn.Conv3d(16, 16, kernel_size=3, padding=1, stride=1),
            nn.BatchNorm3d(16),
            nn.ReLU(),

            nn.MaxPool3d(2),

            # Second Block
            nn.Conv3d(16, 32, kernel_size=3, padding=1, stride=1),
            nn.ReLU(),
    
            nn.Conv3d(32, 32, kernel_size=3, padding=1, stride=1),
            nn.BatchNorm3d(32),
            nn.ReLU(),

            nn.MaxPool3d(2),

            # Third Block
            nn.Conv3d(32, 64, kernel_size=3, padding=1, stride=1),
            nn.ReLU(),

            nn.Conv3d(64, 64, kernel_size=3, padding=1, stride=1),
            nn.BatchNorm3d(64),
            nn.ReLU(),

            nn.MaxPool3d(2),
        )
        
        '''
        self.server_block = nn.Sequential(
            
            # 4th Block
            nn.Conv3d(64, 128, kernel_size=3, padding=1, stride=1),
            nn.ReLU(),

            nn.Conv3d(128, 128, kernel_size=3, padding=1, stride=1),
            nn.BatchNorm3d(128),
            nn.ReLU(),

            nn.MaxPool3d(2),

            # 5th Block
            nn.Conv3d(128, 256, kernel_size=3, padding=1, stride=1),
            nn.ReLU(),

            nn.Conv3d(256, 256, kernel_size=3, padding=1, stride=1),
            nn.BatchNorm3d(256),
            nn.ReLU(),

            nn.MaxPool3d(2),
        )

        self.regressor = nn.Sequential(
            nn.Linear(9216, 1024),
            nn.ReLU(),
            nn.Linear(1024, 1),
        )
        '''

    def forward(self, x):
        x = self.client_block(x)
        return x

# %%
splitnn_client = CNN3DModel().to(device)
print(splitnn_client)
# Out:
# CNN3DModel(
#   (client_block): Sequential(
#     (0): Conv3d(1, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): ReLU()
#     (2): Conv3d(16, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU()
#     (5): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (7): ReLU()
#     (8): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (9): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (13): ReLU()
#     (14): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (15): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU()
#     (17): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
# )

# %% [markdown]
# ## Socket initialization

# %% [markdown]
# ### Required socket functions

# %%
def send_msg(sock, msg):
    # prefix each message with a 4-byte length in network byte order
    msg = pickle.dumps(msg)
    msg = struct.pack('>I', len(msg)) + msg
    sock.sendall(msg)

def recv_msg(sock):
    # read message length and unpack it into an integer
    raw_msglen = recvall(sock, 4)
    if not raw_msglen:
        return None
    msglen = struct.unpack('>I', raw_msglen)[0]
    # read the message data
    msg =  recvall(sock, msglen)
    msg = pickle.loads(msg)
    return msg

def recvall(sock, n):
    # helper function to receive n bytes or return None if EOF is hit
    data = b''
    while len(data) < n:
        packet = sock.recv(n - len(data))
        if not packet:
            return None
        data += packet
    return data

# %% [markdown]
# ### Set host address and port number

# %%
#host = input("IP address: ")
host = '127.0.0.1'
port = 10080

# %% [markdown]
# ## SET TIMER

# %%
start_time = time.time()    # store start time
print("timer start!")
# Out:
# timer start!

# %% [markdown]
# ### Open the client socket

# %%
s = socket.socket()
s.connect((host, port))

# %%
epoch = recv_msg(s) # get epoch
total_batch = len(train_loader)
msg = total_batch
send_msg(s, msg)   # send total_batch of train dataset

# %%
criterion = nn.L1Loss().to(device)
lr = 0.001
optimizer = optim.Adam(splitnn_client.parameters(), lr=lr)

# %% [markdown]
# ## Real training process

# %%
for e in range(epoch):
    client_weights = recv_msg(s)
    splitnn_client.load_state_dict(client_weights)
    splitnn_client.eval()
    i = 1
    for images, labels in tqdm(train_loader, desc='Epoch '+str(e+1)):
        train = images.view(images.shape[0], 1, images.shape[1], images.shape[2],images.shape[3]).to(device, dtype = torch.float32)
        label = labels.to(device)
        # Clear gradients
        optimizer.zero_grad()
        # Forward propagation
        outputs = splitnn_client(train)
        client_output = outputs.clone().detach().requires_grad_(True)
        msg = {
            'client_output': client_output,
            'label': label
        }
        send_msg(s, msg)
        client_grad = recv_msg(s)
        outputs.backward(client_grad)
        optimizer.step()
        if (i == total_batch):
            break;
        i = i+1;
        del outputs
        del client_output
            
    send_msg(s, splitnn_client.state_dict())
# Out:
# Epoch 1:  99%|█████████████████████████████████▌| 67/68 [00:13<00:00,  4.83it/s]
# Epoch 2:  99%|█████████████████████████████████▌| 67/68 [00:10<00:00,  6.32it/s]
# Epoch 3:  99%|█████████████████████████████████▌| 67/68 [00:10<00:00,  6.34it/s]
# Epoch 4:  99%|█████████████████████████████████▌| 67/68 [00:10<00:00,  6.25it/s]
# Epoch 5:  99%|█████████████████████████████████▌| 67/68 [00:10<00:00,  6.33it/s]
# Epoch 6:  99%|█████████████████████████████████▌| 67/68 [00:10<00:00,  6.32it/s]
# Epoch 7:  99%|█████████████████████████████████▌| 67/68 [00:10<00:00,  6.30it/s]
# Epoch 8:  99%|█████████████████████████████████▌| 67/68 [00:10<00:00,  6.33it/s]
# Epoch 9:  99%|█████████████████████████████████▌| 67/68 [00:10<00:00,  6.32it/s]
# Epoch 10:  99%|████████████████████████████████▌| 67/68 [00:10<00:00,  6.32it/s]

# %%
end_time = time.time()  #store end time
print("WorkingTime of ",device ,": {} sec".format(end_time - start_time))
# Out:
# WorkingTime of  cuda:0 : 538.8826248645782 sec

# %%
for images, labels in tqdm(train_loader, desc='Epoch '+str(e+1)):
        train = images.view(images.shape[0], 1, images.shape[1], images.shape[2],images.shape[3]).to(device, dtype = torch.float32)
        label = labels.to(device)
        # Clear gradients
        optimizer.zero_grad()
        # Forward propagation
        outputs = splitnn_client(train)
        print(outputs.shape)
        client_output = outputs.clone().detach().requires_grad_(True)
        print(client_output.shape)
# Out:
# Epoch 10:   4%|█▌                                | 3/68 [00:00<00:13,  4.74it/s]
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# Epoch 10:  13%|████▌                             | 9/68 [00:01<00:04, 13.12it/s]
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# Epoch 10:  22%|███████▎                         | 15/68 [00:01<00:02, 19.49it/s]
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# Epoch 10:  28%|█████████▏                       | 19/68 [00:01<00:02, 22.70it/s]
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# Epoch 10:  37%|████████████▏                    | 25/68 [00:01<00:01, 25.66it/s]
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# Epoch 10:  46%|███████████████                  | 31/68 [00:01<00:01, 27.14it/s]
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# Epoch 10:  54%|█████████████████▉               | 37/68 [00:01<00:01, 27.47it/s]
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# Epoch 10:  63%|████████████████████▊            | 43/68 [00:02<00:00, 27.96it/s]
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# Epoch 10:  72%|███████████████████████▊         | 49/68 [00:02<00:00, 27.83it/s]
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# Epoch 10:  81%|██████████████████████████▋      | 55/68 [00:02<00:00, 27.99it/s]
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# Epoch 10:  90%|█████████████████████████████▌   | 61/68 [00:02<00:00, 28.51it/s]
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# Epoch 10:  99%|████████████████████████████████▌| 67/68 [00:03<00:00, 28.21it/s]
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# torch.Size([5, 64, 14, 17, 14])
# Epoch 10: 100%|█████████████████████████████████| 68/68 [00:03<00:00, 21.29it/s]

# %%
print(client_grad)
# Out:
# tensor([[[[[ 7.3728e-16, -1.8183e-16, -2.7534e-16,  ...,  1.3396e-15,
#             -2.5091e-15, -3.5048e-15],
#            [ 1.7655e-15,  1.2853e-15,  1.0434e-15,  ...,  1.5715e-15,
#             -2.6282e-15, -4.4438e-15],
#            [ 3.8048e-15,  4.2673e-15,  4.0747e-15,  ...,  2.6111e-15,
#             -4.7747e-16, -2.3083e-15],
#            ...,
#            [ 1.0435e-15,  1.2687e-15,  9.2943e-16,  ...,  3.8960e-15,
#             -1.0966e-15, -3.9173e-15],
#            [ 8.8289e-16,  1.4272e-15,  1.3941e-15,  ...,  5.3361e-15,
#             -2.1001e-15, -5.5367e-15],
#            [ 5.3827e-16,  8.6115e-16,  7.6230e-16,  ...,  3.3288e-15,
#             -1.2112e-15, -3.5702e-15]],
#
#           [[ 1.7026e-16, -6.5227e-16, -3.5834e-16,  ..., -3.3426e-15,
#             -3.9088e-15, -2.3731e-15],
#            [ 4.9093e-16, -4.0839e-16, -5.9656e-16,  ..., -6.4972e-15,
#             -4.3146e-15, -1.2166e-15],
#            [ 4.6090e-16, -7.1140e-16, -1.9909e-15,  ..., -6.5432e-15,
#             -3.0811e-15,  7.3165e-17],
#            ...,
#            [ 1.7340e-15,  2.7482e-15,  1.6995e-15,  ..., -8.8928e-15,
#             -9.5719e-15, -5.4557e-15],
#            [ 8.5385e-16,  9.0372e-16, -8.5018e-16,  ..., -5.0043e-15,
#             -5.8769e-15, -3.1733e-15],
#            [-3.2607e-16, -1.4156e-15, -2.7431e-15,  ..., -3.0764e-15,
#             -3.4061e-15, -1.3572e-15]],
#
#           [[ 1.5307e-16, -4.8821e-16, -1.6282e-15,  ..., -4.7517e-15,
#             -1.5695e-15,  7.4169e-16],
#            [-1.8041e-15, -3.4431e-15, -6.9781e-15,  ..., -8.1292e-15,
#             -2.3615e-15,  8.3289e-17],
#            [-4.8336e-15, -7.8336e-15, -1.1308e-14,  ..., -9.6516e-15,
#             -3.7437e-15, -6.1242e-16],
#            ...,
#            [-1.7670e-15, -7.0536e-15, -1.1580e-14,  ..., -2.0364e-14,
#             -1.9969e-14, -1.4313e-14],
#            [-2.0864e-15, -6.7752e-15, -9.9149e-15,  ..., -1.6153e-14,
#             -1.8974e-14, -1.6049e-14],
#            [-1.2667e-15, -3.2568e-15, -3.2922e-15,  ..., -9.1162e-15,
#             -1.1429e-14, -1.1091e-14]],
#
#           ...,
#
#           [[ 1.2278e-15,  3.3849e-15,  2.0529e-15,  ...,  3.0250e-15,
#              3.5142e-15,  4.8971e-15],
#            [ 3.5049e-15,  6.4844e-15,  5.0941e-15,  ...,  6.2961e-15,
#              6.0102e-15,  7.6181e-15],
#            [ 4.7230e-15,  7.4910e-15,  6.8967e-15,  ...,  7.4114e-15,
#              9.0831e-15,  9.2312e-15],
#            ...,
#            [ 2.9471e-15,  8.9590e-15,  6.8038e-15,  ...,  6.2227e-15,
#              3.8846e-15,  6.3623e-15],
#            [ 8.0304e-16,  4.3795e-15,  4.6492e-15,  ...,  3.8636e-15,
#              2.6241e-15,  4.8246e-15],
#            [-1.8965e-15, -8.2499e-17,  1.2318e-15,  ...,  4.1240e-16,
#             -9.1873e-17,  1.8917e-15]],
#
#           [[ 1.9733e-15,  4.2649e-15,  3.6320e-15,  ...,  8.2340e-15,
#              7.8541e-15,  4.7282e-15],
#            [ 4.8314e-15,  7.8276e-15,  5.2042e-15,  ...,  7.5644e-15,
#              7.1651e-15,  3.7407e-15],
#            [ 6.1509e-15,  1.0105e-14,  9.2595e-15,  ...,  1.1149e-14,
#              9.5670e-15,  4.1829e-15],
#            ...,
#            [ 5.2725e-15,  8.2293e-15,  5.7949e-15,  ...,  9.0763e-15,
#              8.4560e-15,  4.6500e-15],
#            [ 3.9727e-15,  6.2071e-15,  3.6408e-15,  ...,  7.0474e-15,
#              6.5983e-15,  8.9024e-16],
#            [ 1.2560e-15,  2.3949e-15,  6.2449e-16,  ...,  2.3847e-15,
#              1.9268e-15,  3.3834e-16]],
#
#           [[ 2.4449e-15,  3.3111e-15,  2.3258e-15,  ...,  1.5775e-15,
#              3.4123e-16,  8.5415e-16],
#            [ 4.1507e-15,  5.4110e-15,  4.2738e-15,  ...,  5.5581e-15,
#              4.5651e-16,  3.3740e-15],
#            [ 5.5354e-15,  7.2740e-15,  8.0539e-15,  ...,  8.2524e-15,
#              4.3352e-15,  5.5447e-15],
#            ...,
#            [ 3.6722e-15,  5.8674e-15,  5.7796e-15,  ...,  5.2624e-15,
#              1.3243e-15,  3.8403e-15],
#            [ 3.5885e-15,  5.3061e-15,  6.5376e-15,  ...,  5.8427e-15,
#              2.9661e-15,  4.2206e-15],
#            [ 1.5162e-15,  2.3526e-15,  2.2629e-15,  ...,  2.6904e-15,
#              1.8165e-15,  1.7645e-15]]],
#
#
#          [[[ 2.9854e-16,  4.2822e-16, -5.4100e-17,  ...,  1.1656e-15,
#             -1.4026e-15, -2.5945e-15],
#            [ 1.4601e-15,  2.0068e-15,  1.5303e-15,  ...,  2.8324e-15,
#             -1.1841e-15, -2.7346e-15],
#            [ 3.3553e-15,  5.0166e-15,  4.0590e-15,  ...,  3.5655e-15,
#              3.4342e-16, -1.4375e-15],
#            ...,
#            [ 1.2165e-15,  9.9363e-16,  3.7825e-16,  ...,  3.5579e-15,
#             -1.6060e-16, -2.5521e-15],
#            [ 1.1393e-15,  1.4700e-15,  9.9013e-16,  ...,  4.3750e-15,
#             -6.8594e-16, -3.5818e-15],
#            [ 6.8058e-16,  9.8848e-16,  8.1717e-16,  ...,  2.8221e-15,
#             -3.2411e-16, -2.1062e-15]],
#
#           [[ 1.7540e-16, -1.4791e-16,  1.0000e-15,  ..., -2.6221e-15,
#             -4.5417e-15, -2.3676e-15],
#            [ 2.0999e-15,  1.7878e-15,  1.7551e-15,  ..., -1.6111e-15,
#             -3.8413e-15, -2.7815e-15],
#            [ 4.4668e-15,  5.3143e-15,  3.6982e-15,  ..., -5.5550e-16,
#             -1.0640e-15, -8.9989e-16],
#            ...,
#            [ 2.5299e-15,  3.0788e-15,  1.1138e-15,  ..., -3.0140e-15,
#             -6.1627e-15, -3.9971e-15],
#            [ 1.6661e-15,  2.1940e-15,  5.4546e-17,  ..., -3.9538e-17,
#             -4.0472e-15, -4.0712e-15],
#            [ 5.6540e-16,  5.2029e-16, -8.4768e-16,  ...,  7.3232e-16,
#             -2.2772e-15, -2.3756e-15]],
#
#           [[ 6.0287e-16,  1.0059e-16,  1.0148e-15,  ..., -4.3381e-15,
#             -3.6288e-15, -1.2944e-15],
#            [ 1.1914e-15, -1.0279e-15, -1.5775e-15,  ..., -5.8401e-15,
#             -4.1813e-15, -1.2861e-15],
#            [ 1.0192e-15, -1.0890e-15, -3.2289e-15,  ..., -6.2026e-15,
#             -2.0447e-15, -1.0073e-15],
#            ...,
#            [ 1.0516e-15, -2.1704e-15, -6.1492e-15,  ..., -1.8003e-14,
#             -1.8239e-14, -1.2931e-14],
#            [-6.2135e-16, -3.4134e-15, -6.3447e-15,  ..., -1.1315e-14,
#             -1.4895e-14, -1.4066e-14],
#            [-3.0023e-16, -1.4356e-15, -2.8704e-15,  ..., -6.2255e-15,
#             -9.4081e-15, -8.0742e-15]],
#
#           ...,
#
#           [[ 3.1687e-15,  2.5061e-15,  2.8437e-15,  ...,  9.1727e-15,
#              7.8183e-15,  3.0666e-15],
#            [ 3.3676e-15,  2.9056e-15,  4.8545e-15,  ...,  9.9612e-15,
#              8.8284e-15,  7.9511e-15],
#            [ 4.6778e-15,  3.5726e-15,  6.3087e-15,  ...,  9.4576e-15,
#              7.5487e-15,  7.7276e-15],
#            ...,
#            [ 7.5014e-15,  4.2406e-15,  4.4056e-15,  ...,  7.4669e-15,
#              3.7277e-15,  4.7044e-15],
#            [ 7.5723e-15,  6.2063e-15,  4.0275e-15,  ...,  7.2841e-15,
#              3.2465e-15,  3.7933e-15],
#            [ 2.1754e-15,  3.4237e-15,  2.1230e-15,  ...,  3.8573e-15,
#              2.5763e-15,  3.3247e-15]],
#
#           [[ 4.1062e-15,  2.4625e-15,  3.3143e-15,  ...,  6.4009e-15,
#              7.1883e-15,  2.0212e-15],
#            [ 4.9055e-15,  4.3850e-15,  5.1338e-15,  ...,  7.6051e-15,
#              6.8755e-15,  5.0145e-15],
#            [ 6.3605e-15,  4.5415e-15,  7.3387e-15,  ...,  1.1643e-14,
#              7.6484e-15,  5.6438e-15],
#            ...,
#            [ 5.5968e-15,  4.4042e-15,  5.9567e-15,  ...,  6.6038e-15,
#              5.3574e-15,  3.8237e-15],
#            [ 5.5150e-15,  3.7315e-15,  6.4479e-15,  ...,  7.9186e-15,
#              4.1436e-15,  3.3032e-15],
#            [ 2.5290e-15,  2.1454e-15,  2.7773e-15,  ...,  3.6505e-15,
#              2.0406e-15,  9.9779e-16]],
#
#           [[ 2.4817e-15,  2.8522e-15,  2.4820e-15,  ...,  5.3291e-15,
#              7.2819e-15,  2.8009e-15],
#            [ 2.5985e-15,  4.2017e-15,  3.0383e-15,  ...,  7.0083e-15,
#              6.0069e-15,  2.8479e-15],
#            [ 2.7641e-15,  3.4359e-15,  3.3717e-15,  ...,  9.7503e-15,
#              9.5477e-15,  4.9350e-15],
#            ...,
#            [ 3.6251e-15,  6.6220e-15,  4.9668e-15,  ...,  6.0256e-15,
#              6.4324e-15,  3.0547e-15],
#            [ 2.7235e-15,  5.3995e-15,  5.4264e-15,  ...,  5.6132e-15,
#              5.9137e-15,  3.8199e-15],
#            [ 1.0879e-15,  2.5492e-15,  2.3973e-15,  ...,  2.4973e-15,
#              2.9842e-15,  1.3113e-15]]],
#
#
#          [[[ 2.5666e-16,  8.4414e-16,  1.1088e-15,  ...,  1.9581e-15,
#              2.9457e-16, -3.6324e-16],
#            [ 9.7793e-16,  2.6458e-15,  3.1870e-15,  ...,  2.3654e-15,
#              1.8960e-16,  6.8245e-17],
#            [ 2.2148e-15,  4.5256e-15,  4.5419e-15,  ...,  2.0312e-15,
#              4.6039e-17,  9.2256e-17],
#            ...,
#            [ 9.0601e-16,  1.1602e-15,  9.4894e-16,  ...,  2.4264e-15,
#              1.5790e-16, -3.7110e-16],
#            [ 7.4894e-16,  1.1424e-15,  7.2179e-16,  ...,  8.4441e-16,
#             -1.0153e-15, -5.5116e-16],
#            [ 4.5712e-16,  5.7439e-16,  2.9934e-16,  ...,  1.7182e-16,
#             -4.1607e-16,  2.0387e-17]],
#
#           [[ 4.4007e-16,  1.1580e-15,  1.5323e-15,  ...,  1.9503e-15,
#             -4.7924e-16, -1.6132e-15],
#            [ 1.8783e-15,  3.5721e-15,  4.1497e-15,  ...,  1.4982e-15,
#             -8.5484e-16, -3.8957e-16],
#            [ 3.9072e-15,  7.4435e-15,  8.0312e-15,  ...,  2.0869e-15,
#              3.4533e-16,  6.0785e-16],
#            ...,
#            [ 1.9968e-15,  8.9785e-16,  2.4554e-16,  ...,  2.0528e-15,
#             -1.4283e-15, -1.9368e-15],
#            [ 1.7130e-15,  9.0689e-16,  6.7698e-16,  ...,  2.0452e-15,
#             -5.6451e-16, -2.1849e-15],
#            [ 5.5801e-16, -5.0939e-17, -4.9322e-16,  ...,  7.6502e-16,
#             -5.4104e-16, -1.1150e-15]],
#
#           [[ 4.9974e-16, -2.2307e-16, -2.5760e-16,  ..., -2.0570e-15,
#             -3.1376e-15, -2.7139e-15],
#            [ 3.0705e-16, -1.4040e-15, -7.0051e-16,  ..., -5.5797e-15,
#             -5.1041e-15, -1.9336e-15],
#            [ 1.5527e-15,  1.8770e-16,  2.0046e-15,  ..., -2.8006e-15,
#             -2.4176e-15, -9.0110e-16],
#            ...,
#            [ 5.1455e-16, -1.8685e-15, -2.0314e-15,  ..., -8.0851e-15,
#             -9.8926e-15, -7.1743e-15],
#            [-1.1260e-16, -1.3073e-15, -2.1515e-15,  ..., -4.8911e-15,
#             -8.4450e-15, -7.8664e-15],
#            [-3.5284e-16, -7.6226e-16, -1.2883e-15,  ..., -2.9681e-15,
#             -4.3455e-15, -3.5025e-15]],
#
#           ...,
#
#           [[ 5.2961e-16, -3.0601e-16, -7.5953e-16,  ..., -1.6595e-16,
#              3.6625e-15,  1.7995e-15],
#            [ 1.2507e-15,  1.9591e-16, -5.2786e-16,  ...,  2.8831e-15,
#              7.3511e-15,  2.0178e-15],
#            [ 2.6702e-15,  1.3947e-16, -1.0462e-15,  ...,  2.5315e-15,
#              5.0006e-15,  2.8908e-15],
#            ...,
#            [ 6.6738e-15,  4.9266e-15,  2.2425e-15,  ..., -1.4914e-16,
#              4.4093e-15,  8.1441e-16],
#            [ 9.0905e-15,  7.9333e-15,  4.1830e-15,  ...,  1.6839e-15,
#              5.4540e-15,  2.9514e-15],
#            [ 3.9634e-15,  4.6555e-15,  1.7388e-15,  ...,  1.9562e-15,
#              2.9935e-15,  1.2831e-15]],
#
#           [[-2.5188e-16, -1.1835e-15, -1.7374e-15,  ..., -8.7298e-16,
#              1.4961e-15,  9.0450e-17],
#            [ 1.2757e-16, -1.4969e-15, -2.6386e-15,  ..., -6.0465e-16,
#              1.7252e-15,  2.2825e-16],
#            [-7.7855e-16, -3.1104e-15, -3.9928e-15,  ..., -1.5568e-15,
#              7.1094e-17,  7.6295e-18],
#            ...,
#            [ 1.2255e-15, -2.1658e-15, -3.4993e-15,  ..., -3.5711e-16,
#              1.2833e-15, -2.7961e-16],
#            [ 2.8158e-16, -2.3168e-15, -3.5927e-15,  ..., -2.8954e-16,
#             -7.7336e-16, -3.4602e-16],
#            [ 1.2337e-16, -3.8460e-16, -1.6389e-15,  ..., -4.0165e-16,
#              3.4128e-16, -5.1632e-16]],
#
#           [[-1.2484e-17,  7.6688e-16,  5.6778e-16,  ...,  1.2954e-15,
#              2.0301e-15,  3.5108e-15],
#            [ 6.1527e-16,  5.0221e-16,  1.0638e-15,  ...,  4.7251e-15,
#              4.0681e-15,  3.4497e-15],
#            [-5.2590e-16, -1.2862e-15, -4.5265e-16,  ...,  3.5795e-15,
#              4.1735e-15,  2.8105e-15],
#            ...,
#            [ 1.8453e-15,  2.7418e-15,  4.5790e-15,  ...,  3.2553e-15,
#              3.7952e-15,  3.5640e-15],
#            [ 1.9578e-15,  2.6792e-15,  3.7761e-15,  ...,  3.0606e-15,
#              4.0211e-15,  2.8854e-15],
#            [ 9.9158e-16,  1.6662e-15,  2.7611e-15,  ...,  2.5188e-15,
#              2.8381e-15,  1.3174e-15]]],
#
#
#          ...,
#
#
#          [[[ 3.1313e-15,  3.3639e-15,  2.2653e-15,  ...,  2.5654e-14,
#              3.5886e-15, -1.4056e-14],
#            [ 8.5640e-15,  1.5530e-14,  1.6572e-14,  ...,  3.5310e-14,
#              8.4313e-15, -1.5071e-14],
#            [ 1.8563e-14,  3.7030e-14,  4.4147e-14,  ...,  3.3982e-14,
#              1.5108e-14, -4.0909e-15],
#            ...,
#            [ 4.3407e-15,  9.9568e-15,  5.6708e-15,  ...,  4.8841e-14,
#              1.9797e-14, -9.8579e-15],
#            [ 3.4593e-15,  9.8496e-15,  9.8626e-15,  ...,  4.9925e-14,
#              1.4621e-14, -1.9216e-14],
#            [ 1.7950e-15,  5.9282e-15,  6.6659e-15,  ...,  2.8861e-14,
#              8.0110e-15, -1.1800e-14]],
#
#           [[-5.0251e-15, -6.8738e-15, -8.6874e-15,  ..., -1.4612e-14,
#             -3.6273e-15, -5.8542e-15],
#            [-1.2128e-14, -1.5051e-14, -1.3390e-14,  ..., -3.8801e-14,
#             -8.5372e-15,  2.3485e-16],
#            [-2.1431e-14, -2.7133e-14, -1.6736e-14,  ..., -4.5231e-14,
#
#           ...,
#
#           [[ 2.0257e-15,  3.6039e-15,  1.3563e-15,  ...,  6.1218e-15,
#              4.9945e-15,  2.4025e-15],
#            [ 2.6070e-15,  3.5255e-15,  3.3698e-15,  ...,  1.0095e-14,
#              1.0115e-14,  3.3488e-15],
#            [ 3.2305e-15,  4.0294e-15,  4.0301e-15,  ...,  1.0146e-14,
#              8.2875e-15,  9.9573e-16],
#            ...,
#            [ 7.7646e-15,  5.8966e-15,  1.3768e-15,  ...,  5.4717e-15,
#              5.3765e-15,  9.1610e-16],
#            [ 7.6945e-15,  2.2476e-15,  5.0274e-16,  ...,  4.2538e-15,
#              7.9333e-17, -1.0104e-15],
#            [ 5.0565e-15,  3.1287e-15,  7.7293e-16,  ...,  3.8955e-15,
#              9.5600e-16, -7.7616e-16]],
#
#           [[ 2.6919e-15,  4.4457e-15,  2.7216e-15,  ...,  5.7067e-15,
#              5.2100e-15,  1.8829e-15],
#            [ 4.0474e-15,  5.3715e-15,  3.2215e-15,  ...,  9.4425e-15,
#              9.9395e-15,  3.6724e-15],
#            [ 5.6531e-15,  7.0159e-15,  6.4368e-15,  ...,  1.1837e-14,
#              1.1099e-14,  2.5562e-15],
#            ...,
#            [ 7.0437e-15,  8.1420e-15,  7.3166e-15,  ...,  8.2021e-15,
#              8.5611e-15,  2.8423e-15],
#            [ 5.5847e-15,  6.8330e-15,  6.3772e-15,  ...,  7.0022e-15,
#              7.6977e-15,  1.5795e-15],
#            [ 2.4919e-15,  3.3486e-15,  2.9858e-15,  ...,  3.4797e-15,
#              3.4565e-15,  2.8610e-16]],
#
#           [[ 2.1979e-15,  3.9894e-15,  3.0387e-15,  ...,  5.9617e-15,
#              7.8311e-15,  3.5307e-15],
#            [ 2.6846e-15,  5.2875e-15,  3.8486e-15,  ...,  8.8465e-15,
#              1.0630e-14,  4.6345e-15],
#            [ 4.0971e-15,  7.0323e-15,  6.3733e-15,  ...,  1.2213e-14,
#              1.4797e-14,  6.5746e-15],
#            ...,
#            [ 4.1442e-15,  8.9490e-15,  8.3591e-15,  ...,  8.3031e-15,
#              8.7877e-15,  3.8115e-15],
#            [ 4.3612e-15,  8.1487e-15,  7.8078e-15,  ...,  8.0757e-15,
#              1.0246e-14,  4.5048e-15],
#            [ 1.6112e-15,  3.1242e-15,  2.7020e-15,  ...,  3.3440e-15,
#              4.5453e-15,  1.2757e-15]]],
#
#
#          [[[ 2.1816e-15,  2.6405e-15,  1.6531e-15,  ...,  1.6053e-14,
#              4.3262e-15, -6.4788e-15],
#            [ 5.9385e-15,  9.9170e-15,  9.6051e-15,  ...,  2.2760e-14,
#              9.6792e-15, -6.2760e-15],
#            [ 1.0399e-14,  2.1308e-14,  2.5342e-14,  ...,  2.0268e-14,
#              1.1264e-14, -1.3863e-15],
#            ...,
#            [ 1.9158e-15,  5.7418e-15,  2.6959e-15,  ...,  2.7539e-14,
#              1.4100e-14, -4.1780e-15],
#            [ 1.0282e-15,  4.7380e-15,  5.1601e-15,  ...,  2.8391e-14,
#            [-2.7702e-14, -2.3179e-14, -2.1111e-14,  ..., -2.5873e-14,
#             -3.9043e-15,  6.3368e-15],
#            [-2.0098e-14, -1.4484e-14, -1.6552e-14,  ..., -2.7760e-14,
#             -2.9941e-15,  4.2202e-15],
#            [-9.8667e-15, -1.0963e-14, -1.2407e-14,  ..., -2.1112e-14,
#             -6.0545e-15, -7.6995e-16]],
#
#           [[-1.2101e-14, -1.8270e-14, -1.8221e-14,  ..., -5.4760e-14,
#             -7.9829e-14, -6.3445e-14],
#            [-1.6591e-14, -2.3555e-14, -2.4674e-14,  ..., -7.4606e-14,
#             -1.0715e-13, -8.5717e-14],
#            [-1.7314e-14, -2.2288e-14, -2.5900e-14,  ..., -8.0478e-14,
#             -1.0793e-13, -8.0412e-14],
#            ...,
#            [-3.3833e-14, -5.3674e-14, -7.0770e-14,  ..., -6.8773e-14,
#             -9.8634e-14, -7.8156e-14],
#            [-2.9007e-14, -4.6002e-14, -6.0555e-14,  ..., -6.7258e-14,
#             -8.7742e-14, -6.6950e-14],
#            [-1.2877e-14, -2.1726e-14, -2.9854e-14,  ..., -3.6718e-14,
#             -4.0691e-14, -2.8821e-14]]]],
#
#
#
#         [[[[ 8.3939e-16,  3.9102e-17, -2.1124e-17,  ...,  1.3420e-15,
#             -2.6011e-15, -3.5173e-15],
#            [ 1.9225e-15,  1.6386e-15,  1.4042e-15,  ...,  1.5678e-15,
#             -2.6187e-15, -4.4526e-15],
#            [ 3.9195e-15,  4.5745e-15,  4.1638e-15,  ...,  2.7207e-15,
#             -3.6309e-16, -2.2478e-15],
#            ...,
#            [ 1.0862e-15,  1.3523e-15,  8.9462e-16,  ...,  4.3213e-15,
#             -9.4694e-16, -3.8240e-15],
#            [ 9.9761e-16,  1.6398e-15,  1.6077e-15,  ...,  5.2009e-15,
#             -1.9663e-15, -5.3638e-15],
#            [ 6.2151e-16,  1.0213e-15,  9.2464e-16,  ...,  3.2392e-15,
#             -1.1505e-15, -3.4650e-15]],
#
#           [[ 2.6789e-16, -5.2568e-16, -3.5785e-16,  ..., -3.3620e-15,
#             -3.9468e-15, -2.3892e-15],
#            [ 5.8707e-16, -2.8541e-16, -7.7123e-16,  ..., -6.5399e-15,
#             -4.3815e-15, -1.2448e-15],
#            [ 4.7396e-16, -7.0911e-16, -2.3032e-15,  ..., -6.6188e-15,
#             -3.1915e-15,  1.4711e-17],
#            ...,
#            [ 2.1518e-15,  3.0312e-15,  1.2758e-15,  ..., -8.9773e-15,
#             -9.5228e-15, -5.5870e-15],
#            [ 1.0260e-15,  9.9364e-16, -9.9039e-16,  ..., -4.9429e-15,
#             -5.8393e-15, -3.1015e-15],
#            [-2.9311e-16, -1.3679e-15, -2.6985e-15,  ..., -2.9876e-15,
#             -3.3943e-15, -1.3243e-15]],
#
#           [[ 1.1849e-16, -6.6955e-16, -2.0186e-15,  ..., -5.1075e-15,
#             -3.2754e-15, -1.2290e-15],
#            [-2.0169e-15, -3.8503e-15, -7.7872e-15,  ..., -9.1560e-15,
#             -4.4911e-15, -2.3637e-15],
#            [-5.1093e-15, -8.2483e-15, -1.2197e-14,  ..., -1.0486e-14,
#             -5.0437e-15, -1.9820e-15],
#            ...,
#            [-1.3983e-15, -6.2263e-15, -1.0399e-14,  ..., -2.0882e-14,
#             -2.1330e-14, -1.5593e-14],
#            [-1.9127e-15, -6.1724e-15, -8.6813e-15,  ..., -1.6600e-14,
#             -1.9773e-14, -1.6829e-14],
#            [-1.0893e-15, -3.0028e-15, -3.1830e-15,  ..., -9.2951e-15,
#             -1.1622e-14, -1.1199e-14]],
#
#           ...,
#
#           [[ 1.1245e-15,  3.2120e-15,  1.8546e-15,  ...,  3.0685e-15,
#              4.2557e-15,  4.7485e-15],
#            [ 3.3590e-15,  6.2790e-15,  4.8932e-15,  ...,  6.2954e-15,
#              5.9189e-15,  7.6534e-15],
#            [ 4.6053e-15,  7.3287e-15,  6.8089e-15,  ...,  6.5015e-15,
#              8.4617e-15,  9.7102e-15],
#            ...,
#            [ 1.0316e-15,  8.9222e-15,  6.9078e-15,  ...,  5.8490e-15,
#              3.5911e-15,  6.5644e-15],
#            [-1.5265e-16,  4.4736e-15,  4.5015e-15,  ...,  3.6132e-15,
#              2.0797e-15,  5.0223e-15],
#            [-1.8489e-15, -8.3280e-17,  1.2548e-15,  ..., -8.2824e-17,
#             -3.9838e-16,  1.8860e-15]],
#
#           [[ 1.8786e-15,  4.0877e-15,  3.4259e-15,  ...,  7.5260e-15,
#              8.1280e-15,  4.8257e-15],
#            [ 4.7246e-15,  7.6669e-15,  5.0327e-15,  ...,  7.4742e-15,
#              7.2090e-15,  3.9629e-15],
#            [ 6.0763e-15,  1.0024e-14,  9.2266e-15,  ...,  1.0648e-14,
#              9.7184e-15,  4.3600e-15],
#            ...,
#            [ 5.2070e-15,  8.1257e-15,  5.8517e-15,  ...,  8.9610e-15,
#              8.5590e-15,  4.7103e-15],
#            [ 3.9043e-15,  6.1397e-15,  3.5524e-15,  ...,  6.8617e-15,
#              6.6411e-15,  8.8349e-16],
#            [ 1.2239e-15,  2.3606e-15,  6.0612e-16,  ...,  2.3366e-15,
#              1.9457e-15,  3.5558e-16]],
#
#           [[ 2.3793e-15,  3.2219e-15,  2.2453e-15,  ...,  2.1589e-15,
#              3.1367e-16,  8.9629e-16],
#            [ 4.0816e-15,  5.2626e-15,  4.1934e-15,  ...,  4.6368e-15,
#              6.4259e-16,  3.4792e-15],
#            [ 5.4654e-15,  7.1919e-15,  7.9954e-15,  ...,  8.5735e-15,
#              4.2927e-15,  5.6812e-15],
#            ...,
#            [ 3.6425e-15,  5.8116e-15,  5.7374e-15,  ...,  5.1924e-15,
#              1.3531e-15,  3.8915e-15],
#            [ 3.5587e-15,  5.2587e-15,  6.4668e-15,  ...,  5.7521e-15,
#              2.9750e-15,  4.2744e-15],
#            [ 1.4988e-15,  2.3236e-15,  2.2123e-15,  ...,  2.6816e-15,
#              1.8298e-15,  1.7790e-15]]],
#
#
#          [[[ 4.1402e-16,  6.4220e-16,  2.3532e-16,  ...,  1.1234e-15,
#             -1.4673e-15, -2.5981e-15],
#            [ 1.6008e-15,  2.3086e-15,  1.8575e-15,  ...,  2.8926e-15,
#             -1.1501e-15, -2.7259e-15],
#            [ 3.4369e-15,  5.1668e-15,  4.1385e-15,  ...,  3.6849e-15,
#              4.8740e-16, -1.3744e-15],
#            ...,
#            [ 1.2605e-15,  1.0717e-15,  3.7262e-16,  ...,  3.9245e-15,
#              2.4014e-19, -2.4783e-15],
#            [ 1.2251e-15,  1.6218e-15,  1.1629e-15,  ...,  4.3748e-15,
#             -5.4853e-16, -3.4586e-15],
#            [ 7.3752e-16,  1.0999e-15,  9.3430e-16,  ...,  2.7543e-15,
#             -2.7729e-16, -2.0170e-15]],
#
#           [[ 3.8747e-16,  1.0415e-16,  1.2346e-15,  ..., -2.6491e-15,
#             -4.4603e-15, -2.3750e-15],
#            [ 2.3403e-15,  2.0210e-15,  1.9003e-15,  ..., -1.5915e-15,
#             -3.7424e-15, -2.7921e-15],
#            [ 4.5548e-15,  5.2754e-15,  3.5743e-15,  ..., -4.8112e-16,
#             -1.0104e-15, -9.0396e-16],
#            ...,
#            [ 2.6721e-15,  3.2264e-15,  6.6214e-16,  ..., -3.1083e-15,
#             -6.1878e-15, -3.9922e-15],
#            [ 1.9492e-15,  2.3978e-15,  8.2042e-17,  ..., -8.8834e-17,
#             -3.8252e-15, -3.9593e-15],
#            [ 6.4013e-16,  6.3983e-16, -7.0665e-16,  ...,  6.7540e-16,
#             -2.1506e-15, -2.3587e-15]],
#
#           [[ 7.4409e-16,  1.1547e-16,  9.4478e-16,  ..., -5.0787e-15,
#             -4.6712e-15, -2.7143e-15],
#            [ 1.2498e-15, -1.3360e-15, -2.1708e-15,  ..., -6.5858e-15,
#             -5.4659e-15, -2.7568e-15],
#            [ 8.2852e-16, -1.8124e-15, -4.2523e-15,  ..., -6.6966e-15,
#             -2.9210e-15, -1.8096e-15],
#            ...,
#            [ 1.4443e-15, -1.7693e-15, -5.6108e-15,  ..., -1.8729e-14,
#             -1.9019e-14, -1.3902e-14],
#            [-3.1965e-16, -2.6530e-15, -5.3873e-15,  ..., -1.1665e-14,
#             -1.5217e-14, -1.4433e-14],
#            [-1.2915e-16, -1.2029e-15, -2.7262e-15,  ..., -6.3310e-15,
#             -9.5098e-15, -8.0778e-15]],
#
#           ...,
#
#           [[ 3.0716e-15,  2.3867e-15,  2.6569e-15,  ...,  9.4262e-15,
#              7.7758e-15,  3.2926e-15],
#            [ 3.3142e-15,  2.8164e-15,  4.7859e-15,  ...,  9.8508e-15,
#              8.8857e-15,  7.9477e-15],
#            [ 4.6359e-15,  3.5221e-15,  6.3582e-15,  ...,  8.6696e-15,
#              7.2144e-15,  7.7446e-15],
#            ...,
#            [ 7.3779e-15,  3.6717e-15,  3.1013e-15,  ...,  7.4727e-15,
#              3.7825e-15,  4.6623e-15],
#            [ 5.7269e-15,  6.0294e-15,  4.4700e-15,  ...,  7.1707e-15,
#              3.5653e-15,  3.7162e-15],
#            [ 2.1145e-15,  3.2711e-15,  2.0691e-15,  ...,  3.5930e-15,
#              2.4139e-15,  3.3022e-15]],
#
#           [[ 4.0151e-15,  2.3709e-15,  3.2383e-15,  ...,  7.3237e-15,
#              7.1541e-15,  2.2249e-15],
#            [ 4.8517e-15,  4.3180e-15,  5.1251e-15,  ...,  7.0974e-15,
#              7.1810e-15,  5.1604e-15],
#            [ 6.2931e-15,  4.4485e-15,  7.4014e-15,  ...,  1.2888e-14,
#              7.5123e-15,  5.6981e-15],
#            ...,
#            [ 5.5535e-15,  4.4113e-15,  5.9069e-15,  ...,  6.6206e-15,
#              5.3576e-15,  3.7504e-15],
#            [ 5.4598e-15,  3.7075e-15,  6.3420e-15,  ...,  7.8291e-15,
#              4.1240e-15,  3.2890e-15],
#            [ 2.5062e-15,  2.1277e-15,  2.6837e-15,  ...,  3.6514e-15,
#              2.0496e-15,  9.9665e-16]],
#
#           [[ 2.4305e-15,  2.7697e-15,  2.4295e-15,  ...,  6.1436e-15,
#              7.3860e-15,  2.9539e-15],
#            [ 2.5649e-15,  4.1827e-15,  3.0066e-15,  ...,  6.2819e-15,
#              6.3187e-15,  2.8702e-15],
#            [ 2.7503e-15,  3.4088e-15,  3.4427e-15,  ...,  1.0441e-14,
#              9.6675e-15,  5.0485e-15],
#            ...,
#            [ 3.5915e-15,  6.5648e-15,  4.9071e-15,  ...,  6.0044e-15,
#              6.4666e-15,  3.0525e-15],
#            [ 2.6937e-15,  5.3439e-15,  5.3439e-15,  ...,  5.5966e-15,
#              5.9307e-15,  3.8270e-15],
#            [ 1.0773e-15,  2.5191e-15,  2.3601e-15,  ...,  2.5106e-15,
#              2.9959e-15,  1.3100e-15]]],
#
#
#          [[[ 3.5481e-16,  1.0067e-15,  1.3121e-15,  ...,  2.0434e-15,
#              3.1268e-16, -3.4714e-16],
#            [ 1.0611e-15,  2.7309e-15,  3.3734e-15,  ...,  2.3802e-15,
#              1.6836e-16,  1.0634e-16],
#            [ 2.2511e-15,  4.3773e-15,  4.5035e-15,  ...,  2.1257e-15,
#              8.8808e-17,  1.5054e-16],
#            ...,
#            [ 9.2247e-16,  1.1312e-15,  9.1708e-16,  ...,  2.5220e-15,
#              2.1864e-16, -3.4201e-16],
#            [ 8.1420e-16,  1.2119e-15,  8.1792e-16,  ...,  1.0114e-15,
#             -1.0263e-15, -5.2243e-16],
#            [ 4.9157e-16,  6.0462e-16,  3.3549e-16,  ...,  1.5813e-16,
#             -4.2313e-16,  3.2913e-17]],
#
#           [[ 5.7660e-16,  1.3506e-15,  1.8322e-15,  ...,  1.9465e-15,
#             -4.0999e-16, -1.6184e-15],
#            [ 2.0015e-15,  3.6358e-15,  4.3356e-15,  ...,  1.5876e-15,
#             -8.6194e-16, -3.4095e-16],
#            [ 3.9006e-15,  7.1085e-15,  7.7751e-15,  ...,  2.2175e-15,
#              4.4353e-16,  6.9389e-16],
#            ...,
#              4.0198e-15,  3.5424e-15],
#            [-5.3735e-16, -1.2436e-15, -5.2315e-16,  ...,  3.8669e-15,
#              4.1913e-15,  2.8648e-15],
#            ...,
#            [ 1.8439e-15,  2.7291e-15,  4.5510e-15,  ...,  3.2702e-15,
#              3.7986e-15,  3.6039e-15],
#            [ 1.9475e-15,  2.6578e-15,  3.7439e-15,  ...,  3.0919e-15,
#              4.0225e-15,  2.9067e-15],
#            [ 9.8210e-16,  1.6518e-15,  2.7243e-15,  ...,  2.5255e-15,
#              2.8465e-15,  1.3277e-15]]],
#
#
#          ...,
#
#
#          [[[ 3.3831e-15,  4.1980e-15,  3.5990e-15,  ...,  2.5995e-14,
#              3.5742e-15, -1.4046e-14],
#            [ 8.7630e-15,  1.6454e-14,  1.8150e-14,  ...,  3.6102e-14,
#              8.9205e-15, -1.4781e-14],
#            [ 1.8128e-14,  3.6839e-14,  4.4054e-14,  ...,  3.5343e-14,
#              1.6430e-14, -3.3252e-15],
#            ...,
#            [ 4.1408e-15,  9.3982e-15,  4.9148e-15,  ...,  5.0096e-14,
#              2.0433e-14, -9.1596e-15],
#            [ 3.6148e-15,  1.0357e-14,  1.0637e-14,  ...,  4.9571e-14,
#              1.4796e-14, -1.8406e-14],
#            [ 1.9501e-15,  6.3825e-15,  7.3532e-15,  ...,  2.7921e-14,
#              7.8121e-15, -1.1397e-14]],
#
#           [[-5.5224e-15, -7.6650e-15, -1.0084e-14,  ..., -1.4907e-14,
#             -3.8423e-15, -5.8145e-15],
#            [-1.2842e-14, -1.6072e-14, -1.5950e-14,  ..., -3.9520e-14,
#             -8.9512e-15,  2.3648e-16],
#            [-2.2337e-14, -2.7635e-14, -1.9032e-14,  ..., -4.6160e-14,
#             -9.5055e-15,  6.3876e-15],
#            ...,
#            [-6.2466e-15,  1.3657e-14,  1.6446e-14,  ..., -3.3388e-14,
#             -2.9412e-14, -2.4401e-14],
#            [-9.7789e-15, -2.3347e-15, -5.1983e-16,  ..., -1.0810e-14,
#             -5.3496e-15, -1.1697e-14],
#            [-9.9385e-15, -1.0725e-14, -1.1621e-14,  ..., -8.7104e-15,
#             -4.2515e-15, -5.8952e-15]],
#
#           [[-8.0400e-15, -1.1006e-14, -3.6173e-14,  ..., -3.2918e-14,
#              3.2684e-14,  3.6467e-14],
#            [-4.6040e-14, -6.5197e-14, -9.9156e-14,  ..., -8.1235e-14,
#              1.6709e-14,  3.9839e-14],
#            [-1.0472e-13, -1.5427e-13, -1.7516e-13,  ..., -1.1760e-13,
#             -2.9841e-14,  1.7058e-14],
#            ...,
#            [-3.0046e-14, -3.6233e-14, -5.3856e-14,  ..., -1.6509e-13,
#             -7.5656e-14, -4.5930e-14],
#            [-2.9840e-14, -4.5455e-14, -5.7493e-14,  ..., -1.2162e-13,
#             -2.6307e-14, -2.1288e-14],
#            [-1.5454e-14, -2.3394e-14, -2.4703e-14,  ..., -6.7622e-14,
#             -1.0601e-14, -1.2316e-14]],
#
#           ...,
#
#            [ 1.4327e-15,  1.1183e-15,  3.7285e-16,  ...,  7.3467e-16,
#             -2.3163e-15, -1.8955e-15]],
#
#           [[ 1.0496e-16, -8.6589e-16,  1.5002e-15,  ..., -3.5361e-15,
#             -4.5255e-15, -1.4889e-15],
#            [ 1.2883e-15,  2.9732e-16,  2.3442e-15,  ..., -4.6808e-15,
#             -5.2231e-15, -2.0585e-15],
#            [ 4.4845e-15,  2.3338e-15,  2.7385e-15,  ..., -2.5101e-15,
#             -2.6117e-15, -1.3082e-15],
#            ...,
#            [ 4.9390e-15,  1.7775e-15, -6.0443e-16,  ..., -4.7322e-15,
#             -7.3412e-15, -3.1280e-15],
#            [ 2.4937e-15,  1.6604e-16, -1.9797e-15,  ..., -4.0967e-15,
#             -8.9969e-15, -2.9138e-15],
#            [ 1.6273e-15,  6.0806e-16, -1.4299e-15,  ..., -2.4547e-15,
#             -5.7334e-15, -2.1570e-15]],
#
#           [[-4.4800e-17, -2.3661e-15, -1.4118e-15,  ..., -4.9099e-15,
#             -4.8289e-15, -1.0049e-15],
#            [-9.0294e-16, -2.9592e-15, -3.2294e-15,  ..., -7.6941e-15,
#             -4.0426e-15, -2.3624e-15],
#            [-1.9361e-15, -6.7421e-15, -6.4271e-15,  ..., -6.2811e-15,
#             -1.5117e-15, -1.7100e-15],
#            ...,
#            [ 3.1010e-15, -5.2314e-15, -8.0155e-15,  ..., -1.8807e-14,
#             -2.1135e-14, -8.0177e-15],
#            [ 3.0378e-16, -5.2149e-15, -7.5783e-15,  ..., -1.5792e-14,
#             -2.1674e-14, -8.3851e-15],
#            [-3.2982e-16, -2.2592e-15, -4.3766e-15,  ..., -1.1058e-14,
#             -1.4014e-14, -6.6124e-15]],
#
#           ...,
#
#           [[ 1.9510e-15,  3.4540e-15,  1.2303e-15,  ...,  4.2396e-15,
#              5.7079e-15,  2.2865e-15],
#            [ 2.5127e-15,  3.4128e-15,  3.2014e-15,  ...,  9.3640e-15,
#              1.0625e-14,  3.4987e-15],
#            [ 3.1695e-15,  3.9473e-15,  3.9366e-15,  ...,  9.8896e-15,
#              8.2649e-15,  1.5489e-15],
#            ...,
#            [ 8.1118e-15,  4.5871e-15,  1.1009e-15,  ...,  5.1993e-15,
#              5.5826e-15,  5.5621e-16],
#            [ 9.0851e-15,  2.3442e-15,  1.0173e-15,  ...,  4.0415e-15,
#             -1.2341e-16, -1.2324e-15],
#            [ 4.9609e-15,  3.1010e-15,  7.0781e-16,  ...,  4.0410e-15,
#              1.1101e-15, -5.1816e-16]],
#
#           [[ 2.6168e-15,  4.3076e-15,  2.6043e-15,  ...,  4.4693e-15,
#              5.2261e-15,  1.8847e-15],
#            [ 3.9434e-15,  5.2922e-15,  3.1509e-15,  ...,  9.5171e-15,
#              1.0129e-14,  3.8052e-15],
#            [ 5.5661e-15,  6.9505e-15,  6.3759e-15,  ...,  1.1489e-14,
#              1.1481e-14,  2.7168e-15],
#            ...,
#            [ 7.0156e-15,  8.0844e-15,  7.2722e-15,  ...,  8.1950e-15,
#              8.7305e-15,  2.9912e-15],
#            [ 5.5440e-15,  6.7010e-15,  6.3429e-15,  ...,  6.8696e-15,
#              7.7197e-15,  1.5126e-15],
#            [ 2.4741e-15,  3.3245e-15,  2.9506e-15,  ...,  3.4637e-15,
#              3.4696e-15,  2.8493e-16]],
#
#           [[ 2.1467e-15,  3.8785e-15,  2.9612e-15,  ...,  5.8566e-15,
#              8.0577e-15,  3.6599e-15],
#            [ 2.6274e-15,  5.1863e-15,  3.7161e-15,  ...,  8.8399e-15,
#              1.0905e-14,  4.7828e-15],
#            [ 4.0406e-15,  6.9524e-15,  6.3012e-15,  ...,  1.2678e-14,
#              1.4989e-14,  6.6791e-15],
#            ...,
#            [ 4.1093e-15,  8.8728e-15,  8.2934e-15,  ...,  8.2194e-15,
#              8.8667e-15,  3.8524e-15],
#            [ 4.3211e-15,  8.0673e-15,  7.7134e-15,  ...,  7.9929e-15,
#              1.0273e-14,  4.5309e-15],
#            [ 1.5902e-15,  3.0824e-15,  2.6451e-15,  ...,  3.3219e-15,
#              4.5609e-15,  1.2822e-15]]],
#
#
#          [[[ 2.3292e-15,  3.0497e-15,  2.3355e-15,  ...,  1.6217e-14,
#              4.3113e-15, -6.4507e-15],
#            [ 5.8584e-15,  1.0085e-14,  1.0104e-14,  ...,  2.3216e-14,
#              1.0002e-14, -6.0693e-15],
#            [ 9.7471e-15,  2.0639e-14,  2.4760e-14,  ...,  2.0975e-14,
#              1.1916e-14, -9.3650e-16],
#            ...,
#            [ 1.7819e-15,  5.4424e-15,  2.3026e-15,  ...,  2.7878e-14,
#              1.4322e-14, -3.8345e-15],
#            [ 9.8107e-16,  4.8440e-15,  5.3737e-15,  ...,  2.7846e-14,
#              1.2412e-14, -7.9619e-15],
#            [-5.2789e-17,  2.4184e-15,  3.7930e-15,  ...,  1.5347e-14,
#              7.7422e-15, -4.7138e-15]],
#
#           [[-3.7305e-15, -5.2027e-15, -6.7690e-15,  ..., -1.0014e-14,
#             -1.1882e-16, -1.2251e-15],
#            [-8.7173e-15, -1.1000e-14, -1.2117e-14,  ..., -2.3934e-14,
#             -1.0474e-15,  3.3260e-15],
#            [-1.5640e-14, -1.9962e-14, -1.3780e-14,  ..., -2.8165e-14,
#             -4.1520e-15,  5.1358e-15],
#            ...,
#            [-8.6094e-15,  5.1947e-15,  7.6101e-15,  ..., -1.8484e-14,
#             -9.9086e-15, -1.0659e-14],
#            [-9.1640e-15, -2.7736e-15, -1.2356e-15,  ..., -7.6692e-15,
#              9.5477e-16, -2.8217e-15],
#            [-6.7192e-15, -5.8013e-15, -5.4387e-15,  ..., -5.8143e-15,
#              3.8067e-16, -6.4203e-16]],
#
#           [[-6.5268e-15, -9.5560e-15, -2.3473e-14,  ..., -2.2690e-14,
#              2.3364e-14,  2.9320e-14],
#            [-3.1534e-14, -4.5486e-14, -6.5476e-14,  ..., -4.7960e-14,
#              1.5881e-14,  3.0692e-14],
#            [-6.8733e-14, -1.0190e-13, -1.1352e-13,  ..., -7.0583e-14,
#             -1.6280e-14,  1.2137e-14],
#            ...,
#            [-2.1069e-14, -2.0456e-14, -2.9811e-14,  ..., -9.2734e-14,
#             -2.8402e-14, -1.2274e-14],
#            [-1.7984e-14, -2.5137e-14, -3.1957e-14,  ..., -6.7365e-14,
#              1.3936e-15,  6.2198e-15],
#            [-8.2258e-15, -1.1737e-14, -1.2218e-14,  ..., -3.3471e-14,
#              7.9532e-15,  5.0046e-15]],
#
#           ...,
#
#           [[-1.0312e-14, -1.3746e-14, -8.9649e-15,  ..., -5.9065e-14,
#             -6.1689e-14, -3.5641e-14],
#            [-1.8686e-14, -2.5306e-14, -2.0191e-14,  ..., -8.3813e-14,
#             -8.2206e-14, -4.5034e-14],
#            [-2.5376e-14, -3.4262e-14, -3.4876e-14,  ..., -7.7281e-14,
#             -6.9723e-14, -3.5551e-14],
#            ...,
#            [-1.0878e-13, -9.9191e-14, -5.1804e-14,  ..., -4.5449e-14,
#             -3.9340e-14, -1.5917e-14],
#            [-1.3082e-13, -1.2720e-13, -6.4157e-14,  ..., -5.9978e-14,
#             -5.8803e-14, -2.7426e-14],
#            [-6.8309e-14, -7.5672e-14, -3.9404e-14,  ..., -4.8419e-14,
#             -5.2538e-14, -2.6291e-14]],
#
#           [[-1.3685e-14, -1.8539e-14, -1.4892e-14,  ..., -2.7664e-14,
#             -1.6889e-14, -5.2381e-15],
#            [-2.1685e-14, -2.8324e-14, -2.5217e-14,  ..., -4.0701e-14,
#             -2.8477e-14, -1.4304e-14],
#            [-2.9681e-14, -3.7352e-14, -3.7246e-14,  ..., -4.6156e-14,
#             -3.5729e-14, -2.2520e-14],
#            ...,
#            [-2.7901e-14, -2.3129e-14, -2.0809e-14,  ..., -2.5121e-14,
#             -3.6246e-15,  6.5157e-15],
#            [-2.0236e-14, -1.4505e-14, -1.6392e-14,  ..., -2.6568e-14,
#             -2.4021e-15,  4.5537e-15],
#            [-1.0027e-14, -1.1119e-14, -1.2419e-14,  ..., -2.0739e-14,
#             -5.9435e-15, -7.9784e-16]],
#
# ...
#              4.1821e-16,  3.8920e-16],
#            ...,
#            [ 9.2954e-16,  1.1444e-15,  9.3102e-16,  ...,  2.4247e-15,
#              2.5426e-16, -1.4735e-16],
#            [ 8.4384e-16,  1.2630e-15,  9.0218e-16,  ...,  8.8688e-16,
#             -1.0917e-15, -7.7358e-16],
#            [ 5.0867e-16,  6.3740e-16,  3.8534e-16,  ...,  1.8091e-16,
#             -4.4809e-16,  1.3342e-18]],
#
#           [[ 1.0192e-15,  1.9069e-15,  3.0080e-15,  ...,  3.2786e-15,
#              2.2863e-16, -1.2329e-15],
#            [ 2.3905e-15,  3.8015e-15,  5.0900e-15,  ...,  2.4797e-15,
#             -4.1763e-16,  2.3439e-16],
#            [ 4.0179e-15,  6.5096e-15,  7.5496e-15,  ...,  2.8486e-15,
#              6.5713e-16,  1.1791e-15],
#            ...,
#            [ 2.3912e-15,  1.1503e-15,  3.5251e-16,  ...,  1.9591e-15,
#             -1.4204e-15, -2.0673e-15],
#            [ 1.8740e-15,  1.2245e-15,  1.0195e-15,  ...,  2.1303e-15,
#             -4.3276e-16, -1.9118e-15],
#            [ 6.2691e-16,  4.6053e-17, -3.8307e-16,  ...,  7.4882e-16,
#             -5.4500e-16, -1.1184e-15]],
#
#           [[ 7.6432e-16, -2.1921e-16, -2.7187e-16,  ..., -1.8347e-15,
#             -3.0644e-15, -2.5768e-15],
#            [ 3.0351e-16, -2.6879e-15, -2.5392e-15,  ..., -6.0935e-15,
#             -5.5733e-15, -1.8916e-15],
#            [ 1.0251e-15, -2.1225e-15, -1.1557e-15,  ..., -3.3840e-15,
#             -2.8930e-15, -7.9055e-16],
#            ...,
#            [ 1.9907e-16, -2.3840e-15, -2.9496e-15,  ..., -8.4145e-15,
#             -1.0372e-14, -7.2013e-15],
#            [-6.0032e-16, -1.6887e-15, -2.7218e-15,  ..., -5.0185e-15,
#             -8.6755e-15, -7.8628e-15],
#            [-7.4582e-16, -1.1154e-15, -1.6221e-15,  ..., -2.9613e-15,
#             -4.4730e-15, -3.5593e-15]],
#
#           ...,
#
#           [[ 4.8672e-16, -3.0040e-16, -7.0545e-16,  ...,  5.6257e-17,
#              3.5516e-15,  1.7724e-15],
#            [ 1.1731e-15,  1.6898e-16, -5.4678e-16,  ...,  2.9328e-15,
#              7.4389e-15,  1.6568e-15],
#            [ 2.5470e-15,  7.0818e-17, -1.0262e-15,  ...,  2.8331e-15,
#              5.1844e-15,  2.8389e-15],
#            ...,
#            [ 6.7196e-15,  5.0568e-15,  2.3528e-15,  ...,  4.8798e-17,
#              4.0861e-15,  4.7861e-16],
#            [ 9.0494e-15,  7.8835e-15,  4.0919e-15,  ...,  7.7101e-16,
#              4.4848e-15,  2.8231e-15],
#            [ 3.9017e-15,  4.4057e-15,  1.4732e-15,  ...,  1.3285e-15,
#              2.7019e-15,  1.4376e-15]],
#
#           [[-2.1939e-16, -1.1303e-15, -1.6744e-15,  ..., -8.3568e-16,
#              2.1263e-15,  3.4090e-17],
#            [ 9.4162e-17, -1.4570e-15, -2.5719e-15,  ..., -8.6703e-16,
#              1.4638e-15,  1.7311e-16],
#            [-6.9400e-16, -3.0742e-15, -3.9557e-15,  ..., -1.3568e-15,
#             -2.2525e-16,  7.1335e-17],
#            ...,
#            [ 1.2173e-15, -2.2654e-15, -3.6743e-15,  ..., -6.0302e-16,
#              1.1871e-15, -2.8519e-16],
#            [ 3.0389e-16, -2.2910e-15, -2.9657e-15,  ..., -7.8112e-16,
#             -7.6793e-16, -3.1547e-16],
#            [ 1.1703e-16, -3.5038e-16, -1.6264e-15,  ..., -8.6115e-16,
#              4.0632e-16, -5.1901e-16]],
#
#           [[-3.0730e-17,  7.3495e-16,  5.4584e-16,  ...,  1.6422e-15,
#              1.7469e-15,  3.5426e-15],
#            [ 5.5351e-16,  4.1924e-16,  1.0106e-15,  ...,  4.7086e-15,
#              4.7228e-15,  3.1744e-15],
#            [-6.1851e-16, -1.2635e-15, -5.0446e-16,  ...,  3.5806e-15,
#              4.2139e-15,  2.6111e-15],
#            ...,
#            [ 1.8573e-15,  2.7413e-15,  4.4563e-15,  ...,  4.2033e-15,
#              3.7660e-15,  3.5852e-15],
#            [ 1.9447e-15,  2.6561e-15,  3.4586e-15,  ...,  3.1910e-15,
#              3.9700e-15,  2.8923e-15],
#            [ 9.7596e-16,  1.6447e-15,  2.6960e-15,  ...,  2.4127e-15,
#              2.8010e-15,  1.3286e-15]]],
#
#
#          ...,
#
#
#          [[[ 3.9320e-15,  6.7123e-15,  8.8726e-15,  ...,  3.4085e-14,
#              7.8541e-15, -1.2758e-14],
#            [ 9.0858e-15,  1.9023e-14,  2.4731e-14,  ...,  4.6947e-14,
#              1.5357e-14, -1.1504e-14],
#            [ 1.7398e-14,  3.7077e-14,  4.6571e-14,  ...,  4.3788e-14,
#              2.2533e-14,  1.8032e-15],
#            ...,
#            [ 3.9530e-15,  8.8770e-15,  4.3460e-15,  ...,  4.7912e-14,
#              1.9437e-14, -9.8809e-15],
#            [ 3.5948e-15,  1.0421e-14,  1.1065e-14,  ...,  5.0051e-14,
#              1.4880e-14, -1.9151e-14],
#            [ 1.9713e-15,  6.5138e-15,  7.7488e-15,  ...,  2.8783e-14,
#              8.5083e-15, -1.1501e-14]],
#
#           [[-7.4679e-15, -1.1232e-14, -1.6372e-14,  ..., -1.4732e-14,
#             -3.5086e-15, -5.7402e-15],
#            [-1.6395e-14, -2.2537e-14, -2.8320e-14,  ..., -4.2132e-14,
#             -9.8274e-15,  2.7616e-17],
#            [-2.6367e-14, -3.3760e-14, -3.1560e-14,  ..., -5.1380e-14,
#             -1.2386e-14,  6.0805e-15],
#            ...,
#            [-5.4599e-15,  1.5726e-14,  2.0999e-14,  ..., -3.1935e-14,
#             -2.8781e-14, -2.4634e-14],
#            [-9.6371e-15, -1.7922e-15,  1.0279e-15,  ..., -1.1686e-14,
#             -6.0952e-15, -1.2313e-14],
#            [-1.0047e-14, -1.0897e-14, -1.2010e-14,  ..., -9.3435e-15,
#             -4.3339e-15, -5.9159e-15]],
#
#           [[-1.8393e-14, -2.8472e-14, -6.6820e-14,  ..., -5.5529e-14,
#              2.5969e-14,  4.1413e-14],
#            [-6.1588e-14, -9.0950e-14, -1.4544e-13,  ..., -1.1405e-13,
#              3.1357e-15,  4.2551e-14],
#            [-1.1923e-13, -1.7606e-13, -2.1489e-13,  ..., -1.5138e-13,
#             -5.0990e-14,  1.0555e-14],
#            ...,
#            [-3.1999e-14, -4.6651e-14, -7.3205e-14,  ..., -1.6034e-13,
#             -6.9867e-14, -3.9601e-14],
#            [-3.3932e-14, -5.9989e-14, -8.2508e-14,  ..., -1.1945e-13,
#             -2.2231e-14, -1.7325e-14],
#            [-1.8378e-14, -3.1518e-14, -3.8061e-14,  ..., -6.7405e-14,
#             -9.5677e-15, -1.1519e-14]],
#
#           ...,
#
#            [ 1.4864e-15,  1.2130e-15,  5.1185e-16,  ...,  7.4027e-16,
#             -2.4920e-15, -1.9340e-15]],
#
#           [[ 6.6834e-16, -3.5606e-16,  2.1534e-15,  ..., -3.3656e-15,
#             -4.5642e-15, -1.6445e-15],
#            [ 2.4343e-15,  1.5622e-15,  3.2865e-15,  ..., -4.6541e-15,
#             -5.0112e-15, -2.1778e-15],
#            [ 5.3324e-15,  2.5853e-15,  2.5454e-15,  ..., -2.5312e-15,
#             -2.0117e-15, -1.3804e-15],
#            ...,
#            [ 5.1834e-15,  2.3453e-15,  6.4999e-16,  ..., -4.7085e-15,
#             -7.4079e-15, -3.2723e-15],
#            [ 2.6185e-15,  5.0315e-16, -1.4837e-15,  ..., -4.2188e-15,
#             -9.3014e-15, -2.8481e-15],
#            [ 1.7006e-15,  6.9186e-16, -1.3392e-15,  ..., -2.4379e-15,
#             -5.8453e-15, -2.2504e-15]],
#
#           [[ 1.6138e-16, -2.9769e-15, -2.6584e-15,  ..., -4.4101e-15,
#             -3.0743e-15, -3.3539e-16],
#            [-6.5165e-16, -3.7420e-15, -5.6326e-15,  ..., -7.1239e-15,
#             -2.0888e-15, -1.3855e-15],
#            [-2.3320e-15, -9.3763e-15, -1.0957e-14,  ..., -6.7095e-15,
#             -8.3574e-16, -1.4912e-15],
#            ...,
#            [ 1.7728e-15, -7.7718e-15, -9.3496e-15,  ..., -1.8343e-14,
#             -2.0202e-14, -7.3804e-15],
#            [-1.1868e-15, -7.6333e-15, -9.3679e-15,  ..., -1.5208e-14,
#             -2.1753e-14, -8.2507e-15],
#            [-1.4527e-15, -3.8694e-15, -6.0411e-15,  ..., -1.0929e-14,
#             -1.3985e-14, -6.5967e-15]],
#
#           ...,
#
#           [[ 1.9105e-15,  3.4093e-15,  1.1996e-15,  ...,  5.5109e-15,
#              5.4923e-15,  2.0980e-15],
#            [ 2.4017e-15,  3.3471e-15,  3.0812e-15,  ...,  9.8197e-15,
#              1.0376e-14,  3.1704e-15],
#            [ 3.0253e-15,  3.6998e-15,  3.7341e-15,  ...,  9.7023e-15,
#              7.6641e-15,  6.7043e-16],
#            ...,
#            [ 7.7813e-15,  6.3260e-15,  2.2396e-15,  ...,  6.0830e-15,
#              5.3003e-15,  9.0642e-16],
#            [ 7.6597e-15,  2.8944e-15,  5.0881e-17,  ...,  3.1378e-15,
#              4.4141e-16, -8.8698e-16],
#            [ 5.0113e-15,  3.0740e-15,  7.8027e-16,  ...,  3.7088e-15,
#              9.9683e-16, -6.7786e-16]],
#
#           [[ 2.5860e-15,  4.2821e-15,  2.6082e-15,  ...,  5.5945e-15,
#              4.8877e-15,  1.9642e-15],
#            [ 3.9628e-15,  5.1121e-15,  3.0789e-15,  ...,  9.2881e-15,
#              1.0434e-14,  3.6275e-15],
#            [ 5.5357e-15,  6.7772e-15,  6.2681e-15,  ...,  1.1343e-14,
#              1.1663e-14,  2.4746e-15],
#            ...,
#            [ 7.0661e-15,  8.6123e-15,  6.7759e-15,  ...,  8.6948e-15,
#              8.7479e-15,  2.8984e-15],
#            [ 5.5479e-15,  6.9147e-15,  6.9696e-15,  ...,  7.7518e-15,
#              7.7126e-15,  1.6545e-15],
#            [ 2.4581e-15,  3.3064e-15,  2.8725e-15,  ...,  3.5329e-15,
#              3.4463e-15,  2.8336e-16]],
#
#           [[ 2.1231e-15,  3.8478e-15,  2.9322e-15,  ...,  5.6738e-15,
#              7.4841e-15,  3.4053e-15],
#            [ 2.6070e-15,  5.0762e-15,  3.7137e-15,  ...,  8.2495e-15,
#              1.0612e-14,  4.5646e-15],
#            [ 4.0448e-15,  6.8799e-15,  6.2736e-15,  ...,  1.1949e-14,
#              1.4909e-14,  6.5233e-15],
#            ...,
#            [ 4.1468e-15,  8.9411e-15,  7.6499e-15,  ...,  8.2208e-15,
#              8.8770e-15,  3.8714e-15],
#            [ 4.3291e-15,  8.0761e-15,  7.9760e-15,  ...,  8.7257e-15,
#              1.0205e-14,  4.5285e-15],
#            [ 1.5838e-15,  3.0682e-15,  2.5951e-15,  ...,  3.1342e-15,
#              4.5104e-15,  1.2799e-15]]],
#
#
#          [[[ 2.5895e-15,  4.1405e-15,  4.9540e-15,  ...,  2.0929e-14,
#              6.8662e-15, -5.8893e-15],
#            [ 5.3144e-15,  1.0189e-14,  1.2027e-14,  ...,  2.9091e-14,
#              1.3629e-14, -4.4450e-15],
#            [ 8.2435e-15,  1.8922e-14,  2.3932e-14,  ...,  2.5421e-14,
#              1.5315e-14,  1.8047e-15],
#            ...,
#            [ 1.6580e-15,  5.1311e-15,  1.9523e-15,  ...,  2.7161e-14,
#              1.3978e-14, -4.4257e-15],
#            [ 9.0393e-16,  4.7061e-15,  5.3454e-15,  ...,  2.8421e-14,
#              1.2387e-14, -8.3070e-15],
#            [-1.0607e-16,  2.3555e-15,  3.8155e-15,  ...,  1.5855e-14,
#              8.1264e-15, -4.7230e-15]],
#
#           [[-5.1281e-15, -8.0279e-15, -1.1445e-14,  ..., -1.0206e-14,
#             -3.6434e-17, -1.3299e-15],
#            [-1.1548e-14, -1.6091e-14, -2.1027e-14,  ..., -2.5936e-14,
#             -1.3876e-15,  2.9695e-15],
#            [-1.8896e-14, -2.4781e-14, -2.2460e-14,  ..., -3.1449e-14,
#             -5.7958e-15,  4.3297e-15],
#            ...,
#            [-8.1512e-15,  5.5239e-15,  8.9866e-15,  ..., -1.6941e-14,
#             -9.5440e-15, -1.0902e-14],
#            [-9.1433e-15, -3.2275e-15, -1.2333e-15,  ..., -8.4034e-15,
#              5.0880e-16, -2.9909e-15],
#            [-6.8243e-15, -5.9644e-15, -5.6726e-15,  ..., -6.1949e-15,
#              3.6489e-16, -5.9003e-16]],
#
#           [[-1.3305e-14, -2.1558e-14, -4.3801e-14,  ..., -3.8333e-14,
#              1.7300e-14,  3.0721e-14],
#            [-4.1705e-14, -6.2342e-14, -9.5109e-14,  ..., -7.0968e-14,
#              4.1401e-15,  2.9811e-14],
#            [-7.8003e-14, -1.1526e-13, -1.3698e-13,  ..., -9.2755e-14,
#             -3.1103e-14,  5.9099e-15],
#            ...,
#            [-2.1565e-14, -2.4698e-14, -3.9872e-14,  ..., -8.9877e-14,
#             -2.5858e-14, -9.4256e-15],
#            [-1.8462e-14, -3.0796e-14, -4.4344e-14,  ..., -6.6521e-14,
#              2.9863e-15,  7.8396e-15],
#            [-8.2665e-15, -1.4442e-14, -1.8129e-14,  ..., -3.3500e-14,
#              8.3870e-15,  5.5208e-15]],
#
#           ...,
#
#           [[-1.0155e-14, -1.3572e-14, -8.8857e-15,  ..., -5.9241e-14,
#             -6.0567e-14, -3.5186e-14],
#            [-1.8358e-14, -2.4675e-14, -1.9395e-14,  ..., -8.4741e-14,
#             -8.2077e-14, -4.3976e-14],
#            [-2.4820e-14, -3.3768e-14, -3.3893e-14,  ..., -8.2870e-14,
#             -6.8846e-14, -3.3604e-14],
#            ...,
#            [-9.5176e-14, -8.5283e-14, -3.9378e-14,  ..., -4.2890e-14,
#             -3.5873e-14, -1.3422e-14],
#            [-1.1789e-13, -1.1159e-13, -5.3755e-14,  ..., -4.9264e-14,
#             -4.8862e-14, -2.4589e-14],
#            [-6.9251e-14, -7.5512e-14, -3.8191e-14,  ..., -3.6186e-14,
#             -4.1903e-14, -2.3008e-14]],
#
#           [[-1.3580e-14, -1.8427e-14, -1.4854e-14,  ..., -2.5984e-14,
#             -1.5491e-14, -4.0732e-15],
#            [-2.1324e-14, -2.7895e-14, -2.4772e-14,  ..., -3.8369e-14,
#             -2.6466e-14, -1.2359e-14],
#            [-2.9281e-14, -3.6794e-14, -3.6571e-14,  ..., -4.4114e-14,
#             -3.3213e-14, -2.0418e-14],
#            ...,
#            [-2.7717e-14, -2.7649e-14, -2.4853e-14,  ..., -2.5291e-14,
#             -4.1668e-15,  5.5178e-15],
#            [-2.0131e-14, -1.8788e-14, -2.1093e-14,  ..., -2.4558e-14,
#             -2.6449e-15,  3.7980e-15],
#            [-9.8121e-15, -1.0872e-14, -1.2211e-14,  ..., -1.8478e-14,
#             -5.3196e-15, -8.6530e-16]],
#
#           [[-1.1707e-14, -1.7722e-14, -1.7692e-14,  ..., -5.3191e-14,
#             -7.9125e-14, -6.3918e-14],
#            [-1.5902e-14, -2.2767e-14, -2.4003e-14,  ..., -7.2834e-14,
#             -1.0592e-13, -8.5712e-14],
#            [-1.6819e-14, -2.1643e-14, -2.5527e-14,  ..., -7.7695e-14,
#             -1.0604e-13, -8.0314e-14],
#            ...,
#            [-3.3768e-14, -5.3547e-14, -6.5251e-14,  ..., -6.5719e-14,
#             -9.7894e-14, -7.7918e-14],
#            [-2.8730e-14, -4.5557e-14, -6.0684e-14,  ..., -6.3783e-14,
#             -8.6793e-14, -6.6519e-14],
#            [-1.2663e-14, -2.1385e-14, -2.9026e-14,  ..., -3.5570e-14,
#             -4.0135e-14, -2.8570e-14]]]]], device='cuda:0')

# %%
print(client_grad.shape)
# Out:
# torch.Size([5, 64, 14, 17, 14])
